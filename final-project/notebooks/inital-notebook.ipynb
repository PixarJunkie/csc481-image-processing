# %%
#Import packages 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# import keras 
# import tensorflow
import cv2
import os 
import PIL as image

# %%
#Image path 
img_dir = r'/Users/abbychinn/Desktop/KB/csc481-image-processing/final-project/images/contains-mickey'

# %%
#Load image 
img_name = img_dir + '/' +os.listdir(img_dir)[5]
img = cv2.imread(img_name)
#Convert to rgb
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img2)
# #Hide axes 
plt.xticks([]), plt.yticks([])
plt.show()
